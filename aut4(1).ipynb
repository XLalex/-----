# %%
mu = 0.14
S_0 = 108
S_T = 1
t_max = 1.0
M = 1000
q_1 = 1
q_2 = 1
q_3 = 1
r = 0.05
b_0 = 1000

# Difference equations 
for i in range(M):
    t = 0
    St = S_0
    bT[i] = b_0
    while t < t_max:
        Wt = np.random.normal(0, np.sqrt(dt))
        St = St + mu * St * dt + (t * St) * Wt
        bT[i] = bT[i] - abs(q_1 + q_2 * t) * St
        t += dt
        bT[i] = bT[i] + q_3 * max(St - S_T, 0) + q_3 * max(St + S_T, 0) + b_0 * np.exp(r * t_max)


          
     import numpy as 
     # Parameters 
     mu = 0.14 
     t_max = 1
    M = 1000 
     # Initialize 
      St =     np.ones(M)
     # Alternative Scheme for i in range(M):
      Wt = np.random.normal(0, t_max)
    St[i] = St[i] * np.exp(mu * t_max + (t_max * St[i]) * Wt)

    # Estimating the Mean of ST

 import numpy as np 
import matplotlib.pyplot as plt 

# Parameters 
mu = 0.14
 t_max = 1
 M = 1000 

# Initialize 
t = np.linspace(0, t_max, 1000)
 mean_St = np.zeros(1000)

 # Estimating the Mean of ST
 for i in range(len(t)):
 dt = t[i] / M
 St = np.ones(M)
 for j in range(M):
 Wt = np.random.normal(0, np.sqrt(dt))
 St[j] = St[j] + mu*St[j]*dt + (t[i] * St[j]) * Wt 
mean_St[i] = np.mean(St)


       
import numpy as np

 # Parameters
 #  mu = 0.14
  t_max = 1
 M = 1000 
 q1 = 1
 q2 = 1 
q3 = 1 
  r = 0.05

 # Initialize
 b0 = 1000
 bT = np.zeros(M)
                                     
  # Difference Equations

   for i in range(M)
  t = 0
  St = 1
 while t < t_max                  
 Wt = np.random.normal(0, np.sqrt(dt)) St = St + mu*St*dt + (t *                                         St) * Wt                                      
 bT[i] = bT[i] - abs(q1 + q2 * t) * St
  t += dt
  bT[i] = bT[i] + q3 * max(St - 94, 0) + q3 * max(St + 109, 0) +        b0 * np.exp(r * t_max)
